# %%
import matplotlib.pyplot as plt

# %%
x = ["iphone","vivo","sumsung","oppo"]
y = [85,60,50,40]
plt.xlabel("Brand names",fontsize=20)
plt.ylabel("Trend")
plt.title("Bar graph",fontsize=20)
plt.bar(x,y,color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt

x = ["Oddi","BMW","Rolls Royes","G-Wagon"]
y = [85,70,19,55]
plt.xlabel("Peoples Have")
plt.ylabel("Expensive cars")
a=["m","b","y","g"]
plt.bar(x,y,width=0.5,color=a,edgecolor="black",line)
plt.show()
